# %%
import pandas as pd

# %%
df = pd.read_csv("school_salary.csv")

# %%
df.columns
# Out:
# Index(['student_id', 'cgpa', 'branch', 'college_tier', 'python_skill',
#        'dsa_skill', 'ml_skill', 'web_dev_skill', 'coding_score',
#        'communication_score', 'aptitude_score', 'internships', 'projects',
#        'backlogs', 'resume_score', 'skill_score', 'placed', 'company_type',
#        'job_role', 'salary_lpa'],
#       dtype='object')

# %%
df.set_index("student_id").head(3)
#df.reset_index()
# Out:
#             cgpa branch  college_tier  python_skill  dsa_skill  ml_skill  \
# student_id
# S0          6.87  Civil             1             1          1         0
# S1          6.52  Civil             2             1          0         0
# S2          5.33     IT             1             1          1         1
#
#             web_dev_skill  coding_score  communication_score  aptitude_score  \
# student_id
# S0                      0          15.6                  4.3            92.0
# S1                      1          13.9                  5.8            62.0
# S2                      0           9.8                  8.1            66.4
#
#             internships  projects  backlogs  resume_score  skill_score  \
# student_id
# S0                    1         3         0          62.6            2
# S1                    1         6         0          77.5            2
# S2                    0         5         1          76.0            3
#
# ...

# %%
df["branch"].value_counts()
# Out:
# branch
# IT            1564
# Civil         1504
# ECE           1499
# CSE           1496
# EEE           1478
# Mechanical    1459
# Name: count, dtype: int64

# %%
df.nunique()
# Out:
# student_id             9000
# cgpa                    501
# branch                    6
# college_tier              3
# python_skill              2
# dsa_skill                 2
# ml_skill                  2
# web_dev_skill             2
# coding_score           1001
# communication_score      61
# aptitude_score          601
# internships               4
# projects                  6
# backlogs                  4
# resume_score            893
# skill_score               5
# placed                    2
# company_type              4
# job_role                  4
# salary_lpa             4343
# dtype: int64

# %%
df.job_role.value_counts()
# Out:
# job_role
# Web Developer        1939
# Data Scientist       1938
# Software Engineer    1937
# Analyst              1888
# Name: count, dtype: int64

# %%
# 1298 kisinin isi yok
unemployee_df = df[df["job_role"].isnull()]

# %%
df[df["job_role"]== "Data Scientist"].coding_score.describe()
# Out:
# count    1938.000000
# mean       51.718782
# std        28.480030
# min         0.000000
# 25%        27.800000
# 50%        52.200000
# 75%        76.300000
# max       100.000000
# Name: coding_score, dtype: float64

# %%
#data scientist isleri icin coding scoru dusuk olup nasil ise giris yaptiklarina baktim
df[df["job_role"]== "Data Scientist"].sort_values("coding_score")
# Out:
#      student_id  cgpa      branch  college_tier  python_skill  dsa_skill  \
# 7501      S7501  9.59         ECE             1             1          1
# 7437      S7437  9.01         CSE             3             1          1
# 4534      S4534  7.56         EEE             3             1          1
# 8680      S8680  6.14          IT             2             0          1
# 1620      S1620  8.34  Mechanical             1             1          1
# ...         ...   ...         ...           ...           ...        ...
# 7439      S7439  7.88  Mechanical             3             1          1
# 2051      S2051  5.80  Mechanical             2             1          0
# 4981      S4981  6.89       Civil             1             1          0
# 6907      S6907  8.75         ECE             1             1          1
# 1761      S1761  8.61       Civil             1             1          1
#
#       ml_skill  web_dev_skill  coding_score  communication_score  \
# ...

# %%
#hem issiz olmayan hemde coding score u 10 nun altinda olan veriyi gormek istedim
df[(df["coding_score"]<10.0) & (~df["job_role"].isnull())].sort_values("coding_score")
# Out:
#      student_id  cgpa branch  college_tier  python_skill  dsa_skill  ml_skill  \
# 4163      S4163  5.44    CSE             1             0          1         0
# 7501      S7501  9.59    ECE             1             1          1         1
# 4846      S4846  7.30    EEE             1             1          1         0
# 6486      S6486  7.82    CSE             1             1          0         0
# 7437      S7437  9.01    CSE             3             1          1         1
# ...         ...   ...    ...           ...           ...        ...       ...
# 1522      S1522  8.95    ECE             2             0          1         0
# 1133      S1133  9.69    ECE             3             0          1         0
# 1007      S1007  5.68    ECE             1             1          1         1
# 763        S763  7.44    CSE             1             1          1         0
# 8437      S8437  9.66     IT             1             1          1         1
#
# ...
